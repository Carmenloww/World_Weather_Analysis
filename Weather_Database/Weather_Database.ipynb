# palabuhanratu id
# dingle ie
# hilo us
# leningradskiy ru
# jamestown sh
# port alfred za
# turukhansk ru
# comodoro rivadavia ar
# cape town za
# whyalla au
# beruwala lk
# jamestown sh
# san rafael ar
# mataura pf
# sulurpeta in
# taolanaro mg
# northam au
# porto velho br
# saint-philippe re
# attawapiskat ca
# east london za
# cape town za
# bluff nz
# ushuaia ar

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f8f9304ef03d74666ff24bbb290a769a

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
    
         # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | norman wells
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | cidreira
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | barcelos
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | lamar
# Processing Record 12 of Set 1 | narsaq
# Processing Record 13 of Set 1 | vaini
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | aguimes
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | camocim
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | kisangani
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | deputatskiy
# Processing Record 25 of Set 1 | ust-tarka
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | roald
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | higuey
# City not found. Skipping...
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | ribeira grande
# Processing Record 34 of Set 1 | talas
# Processing Record 35 of Set 1 | middelburg
# Processing Record 36 of Set 1 | bilma
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | mindelo
# Processing Record 40 of Set 1 | port-cartier
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 43 of Set 1 | shihezi
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | tura
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | atuona
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | oriximina
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | cayenne
# Processing Record 3 of Set 2 | ekhabi
# Processing Record 4 of Set 2 | tuatapere
# Processing Record 5 of Set 2 | basco
# Processing Record 6 of Set 2 | hualmay
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | ardmore
# Processing Record 9 of Set 2 | nemuro
# Processing Record 10 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 2 | grand gaube
# Processing Record 12 of Set 2 | lebowakgomo
# Processing Record 13 of Set 2 | veraval
# Processing Record 14 of Set 2 | rosarito
# Processing Record 15 of Set 2 | surt
# Processing Record 16 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | hobyo
# Processing Record 20 of Set 2 | vallenar
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | praia da vitoria
# Processing Record 23 of Set 2 | kaoma
# Processing Record 24 of Set 2 | hit
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | hudson bay
# Processing Record 28 of Set 2 | kenai
# Processing Record 29 of Set 2 | the valley
# Processing Record 30 of Set 2 | bintulu
# Processing Record 31 of Set 2 | moree
# Processing Record 32 of Set 2 | saint-augustin
# Processing Record 33 of Set 2 | nadym
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | north bay
# Processing Record 36 of Set 2 | panguna
# Processing Record 37 of Set 2 | ostrovnoy
# Processing Record 38 of Set 2 | sao filipe
# Processing Record 39 of Set 2 | vao
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 42 of Set 2 | muli
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 2 | takoradi
# Processing Record 46 of Set 2 | santiago del estero
# Processing Record 47 of Set 2 | grindavik
# Processing Record 48 of Set 2 | coihaique
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | kompaniyivka
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | pilar
# Processing Record 3 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 4 of Set 3 | kupang
# Processing Record 5 of Set 3 | shimoda
# Processing Record 6 of Set 3 | alofi
# Processing Record 7 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 3 | san quintin
# Processing Record 9 of Set 3 | hellin
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | alice springs
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | arlit
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | bat yam
# Processing Record 16 of Set 3 | bambous virieux
# Processing Record 17 of Set 3 | maceio
# Processing Record 18 of Set 3 | khasan
# Processing Record 19 of Set 3 | teguise
# Processing Record 20 of Set 3 | mataura
# Processing Record 21 of Set 3 | hamilton
# Processing Record 22 of Set 3 | tilichiki
# Processing Record 23 of Set 3 | coari
# Processing Record 24 of Set 3 | erzin
# Processing Record 25 of Set 3 | pacifica
# Processing Record 26 of Set 3 | ahuimanu
# Processing Record 27 of Set 3 | lafia
# Processing Record 28 of Set 3 | mahebourg
# Processing Record 29 of Set 3 | ossora
# Processing Record 30 of Set 3 | bwanga
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | amherstburg
# Processing Record 33 of Set 3 | souillac
# Processing Record 34 of Set 3 | laguna
# Processing Record 35 of Set 3 | bonthe
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | hukuntsi
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | aripuana
# Processing Record 40 of Set 3 | coquimbo
# Processing Record 41 of Set 3 | wattegama
# Processing Record 42 of Set 3 | maltahohe
# Processing Record 43 of Set 3 | carutapera
# Processing Record 44 of Set 3 | suamico
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | saint anthony
# Processing Record 48 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | carauari
# Processing Record 1 of Set 4 | sao joao da barra
# Processing Record 2 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 3 of Set 4 | emerald
# Processing Record 4 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 4 | da nang
# Processing Record 6 of Set 4 | codrington
# Processing Record 7 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | mount gambier
# Processing Record 10 of Set 4 | muros
# Processing Record 11 of Set 4 | patacamaya
# Processing Record 12 of Set 4 | smithers
# Processing Record 13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | hilo
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | manitouwadge
# Processing Record 17 of Set 4 | college
# Processing Record 18 of Set 4 | salalah
# Processing Record 19 of Set 4 | kanniyakumari
# Processing Record 20 of Set 4 | kholodnyy
# Processing Record 21 of Set 4 | altay
# Processing Record 22 of Set 4 | takhtamygda
# Processing Record 23 of Set 4 | vanimo
# Processing Record 24 of Set 4 | bathsheba
# Processing Record 25 of Set 4 | boden
# Processing Record 26 of Set 4 | samarai
# Processing Record 27 of Set 4 | tatvan
# Processing Record 28 of Set 4 | half moon bay
# Processing Record 29 of Set 4 | lobito
# Processing Record 30 of Set 4 | enumclaw
# Processing Record 31 of Set 4 | kapaa
# Processing Record 32 of Set 4 | camacha
# Processing Record 33 of Set 4 | pevek
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | liverpool
# Processing Record 36 of Set 4 | mayskiy
# Processing Record 37 of Set 4 | te anau
# Processing Record 38 of Set 4 | hunchun
# Processing Record 39 of Set 4 | dunedin
# Processing Record 40 of Set 4 | clyde river
# Processing Record 41 of Set 4 | dodge city
# Processing Record 42 of Set 4 | lagoa
# Processing Record 43 of Set 4 | kawalu
# Processing Record 44 of Set 4 | nortelandia
# Processing Record 45 of Set 4 | san jose
# Processing Record 46 of Set 4 | oistins
# Processing Record 47 of Set 4 | sisimiut
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | kavieng
# Processing Record 50 of Set 4 | dikson
# Processing Record 1 of Set 5 | camopi
# Processing Record 2 of Set 5 | chokurdakh
# Processing Record 3 of Set 5 | morehead
# Processing Record 4 of Set 5 | upernavik
# Processing Record 5 of Set 5 | dubbo
# Processing Record 6 of Set 5 | puerto quijarro
# Processing Record 7 of Set 5 | urusha
# Processing Record 8 of Set 5 | kasempa
# Processing Record 9 of Set 5 | kihei
# Processing Record 10 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 5 | moron
# Processing Record 12 of Set 5 | birin
# Processing Record 13 of Set 5 | riyadh
# Processing Record 14 of Set 5 | abalak
# Processing Record 15 of Set 5 | provideniya
# Processing Record 16 of Set 5 | baghdad
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | ozinki
# Processing Record 20 of Set 5 | irece
# Processing Record 21 of Set 5 | oksfjord
# Processing Record 22 of Set 5 | diamantino
# Processing Record 23 of Set 5 | axim
# Processing Record 24 of Set 5 | caravelas
# Processing Record 25 of Set 5 | mosquera
# Processing Record 26 of Set 5 | channel-port aux basques
# Processing Record 27 of Set 5 | canutama
# Processing Record 28 of Set 5 | ponta do sol
# Processing Record 29 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 5 | tenenkou
# Processing Record 31 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 5 | kodiak
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 35 of Set 5 | richards bay
# Processing Record 36 of Set 5 | stephenville
# Processing Record 37 of Set 5 | abong mbang
# Processing Record 38 of Set 5 | whitehorse
# Processing Record 39 of Set 5 | san matias
# Processing Record 40 of Set 5 | rock sound
# Processing Record 41 of Set 5 | tinqueux
# Processing Record 42 of Set 5 | ongandjera
# Processing Record 43 of Set 5 | lompoc
# Processing Record 44 of Set 5 | ketchenery
# City not found. Skipping...
# Processing Record 45 of Set 5 | qasigiannguit
# Processing Record 46 of Set 5 | gomez
# Processing Record 47 of Set 5 | nizhniy tsasuchey
# Processing Record 48 of Set 5 | lorengau
# Processing Record 49 of Set 5 | kavaratti
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | kaka
# Processing Record 2 of Set 6 | sid
# Processing Record 3 of Set 6 | machico
# Processing Record 4 of Set 6 | newport
# Processing Record 5 of Set 6 | rodrigues alves
# Processing Record 6 of Set 6 | tautira
# Processing Record 7 of Set 6 | dinguiraye
# Processing Record 8 of Set 6 | sungai besar
# Processing Record 9 of Set 6 | shingu
# Processing Record 10 of Set 6 | mehamn
# Processing Record 11 of Set 6 | atar
# Processing Record 12 of Set 6 | puerto cabezas
# Processing Record 13 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 14 of Set 6 | shwebo
# Processing Record 15 of Set 6 | qunduz
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | praia
# Processing Record 18 of Set 6 | cassilandia
# Processing Record 19 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 6 | hasaki
# Processing Record 21 of Set 6 | kashi
# Processing Record 22 of Set 6 | aklavik
# Processing Record 23 of Set 6 | oparino
# Processing Record 24 of Set 6 | north bend
# Processing Record 25 of Set 6 | induno olona
# Processing Record 26 of Set 6 | kieta
# Processing Record 27 of Set 6 | rabo de peixe
# Processing Record 28 of Set 6 | kurilsk
# Processing Record 29 of Set 6 | okoneshnikovo
# Processing Record 30 of Set 6 | dakoro
# Processing Record 31 of Set 6 | palauig
# Processing Record 32 of Set 6 | bechem
# Processing Record 33 of Set 6 | bafq
# Processing Record 34 of Set 6 | nushki
# Processing Record 35 of Set 6 | poum
# Processing Record 36 of Set 6 | krasnoselkup
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | ried
# Processing Record 39 of Set 6 | tran
# Processing Record 40 of Set 6 | iquitos
# Processing Record 41 of Set 6 | octeville
# Processing Record 42 of Set 6 | san cristobal
# Processing Record 43 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 6 | naryan-mar
# Processing Record 46 of Set 6 | ostersund
# Processing Record 47 of Set 6 | butaritari
# Processing Record 48 of Set 6 | victoria
# Processing Record 49 of Set 6 | nanortalik
# Processing Record 50 of Set 6 | leningradskiy
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | sao sepe
# Processing Record 3 of Set 7 | minab
# Processing Record 4 of Set 7 | gizo
# Processing Record 5 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 7 | hithadhoo
# Processing Record 7 of Set 7 | zhezkazgan
# Processing Record 8 of Set 7 | leh
# Processing Record 9 of Set 7 | bakchar
# Processing Record 10 of Set 7 | yulara
# Processing Record 11 of Set 7 | luis correia
# Processing Record 12 of Set 7 | santa maria
# Processing Record 13 of Set 7 | petatlan
# Processing Record 14 of Set 7 | khalkhal
# Processing Record 15 of Set 7 | heidenreichstein
# Processing Record 16 of Set 7 | kamina
# Processing Record 17 of Set 7 | mamanguape
# Processing Record 18 of Set 7 | shaartuz
# City not found. Skipping...
# Processing Record 19 of Set 7 | nichinan
# Processing Record 20 of Set 7 | sur
# Processing Record 21 of Set 7 | manzil salim
# Processing Record 22 of Set 7 | bud
# Processing Record 23 of Set 7 | macau
# Processing Record 24 of Set 7 | nouakchott
# Processing Record 25 of Set 7 | zhigansk
# Processing Record 26 of Set 7 | kutum
# Processing Record 27 of Set 7 | vila
# Processing Record 28 of Set 7 | matara
# Processing Record 29 of Set 7 | bejar
# Processing Record 30 of Set 7 | estevan
# Processing Record 31 of Set 7 | fort nelson
# Processing Record 32 of Set 7 | xuddur
# Processing Record 33 of Set 7 | saint-pierre
# Processing Record 34 of Set 7 | san patricio
# Processing Record 35 of Set 7 | muisne
# Processing Record 36 of Set 7 | baglung
# Processing Record 37 of Set 7 | chapais
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | mandalgovi
# Processing Record 17 of Set 9 | kruisfontein
# Processing Record 18 of Set 9 | torbay
# Processing Record 19 of Set 9 | viedma
# Processing Record 20 of Set 9 | eureka
# Processing Record 21 of Set 9 | port lincoln
# Processing Record 22 of Set 9 | ulaanbaatar
# Processing Record 23 of Set 9 | havre-saint-pierre
# Processing Record 24 of Set 9 | kazerun
# Processing Record 25 of Set 9 | dingle
# Processing Record 26 of Set 9 | evensk
# Processing Record 27 of Set 9 | chapadinha
# Processing Record 28 of Set 9 | bandarbeyla
# Processing Record 29 of Set 9 | tecoanapa
# Processing Record 30 of Set 9 | omboue
# Processing Record 31 of Set 9 | saint-georges
# Processing Record 32 of Set 9 | taganak
# Processing Record 33 of Set 9 | jiblah
# Processing Record 34 of Set 9 | vanderhoof
# Processing Record 35 of Set 9 | severo-kurilsk
# Processing Record 36 of Set 9 | russell
# Processing Record 37 of Set 9 | margate
# Processing Record 38 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 9 | maua
# Processing Record 40 of Set 9 | petropavlovskoye
# Processing Record 41 of Set 9 | seguin
# Processing Record 42 of Set 9 | taoudenni
# Processing Record 43 of Set 9 | goderich
# Processing Record 44 of Set 9 | daru
# Processing Record 45 of Set 9 | benin
# Processing Record 46 of Set 9 | marzuq
# Processing Record 47 of Set 9 | matagami
# Processing Record 48 of Set 9 | sao jose da coroa grande
# Processing Record 49 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 50 of Set 9 | merauke
# Processing Record 1 of Set 10 | koryazhma
# Processing Record 2 of Set 10 | karasjok
# Processing Record 3 of Set 10 | sola
# Processing Record 4 of Set 10 | tigil
# Processing Record 5 of Set 10 | komsomolskiy
# Processing Record 6 of Set 10 | hwange
# Processing Record 7 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 8 of Set 10 | palestine
# Processing Record 9 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 10 of Set 10 | zolotukhino
# Processing Record 11 of Set 10 | makurdi
# Processing Record 12 of Set 10 | masvingo
# Processing Record 13 of Set 10 | taltal
# Processing Record 14 of Set 10 | chifeng
# Processing Record 15 of Set 10 | poyarkovo
# Processing Record 16 of Set 10 | meghraj
# Processing Record 17 of Set 10 | shaowu
# Processing Record 18 of Set 10 | northam
# Processing Record 19 of Set 10 | williams lake
# Processing Record 20 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 10 | carballo
# Processing Record 22 of Set 10 | gouyave
# Processing Record 23 of Set 10 | pampa
# Processing Record 24 of Set 10 | molina
# Processing Record 25 of Set 10 | xining
# Processing Record 26 of Set 10 | paamiut
# Processing Record 27 of Set 10 | bousso
# Processing Record 28 of Set 10 | marystown
# Processing Record 29 of Set 10 | portland
# Processing Record 30 of Set 10 | shebunino
# Processing Record 31 of Set 10 | bauska
# Processing Record 32 of Set 10 | porbandar
# Processing Record 33 of Set 10 | leshan
# Processing Record 34 of Set 10 | la rioja
# Processing Record 35 of Set 10 | beringovskiy
# Processing Record 36 of Set 10 | guerrero negro
# Processing Record 37 of Set 10 | vardo
# Processing Record 38 of Set 10 | balkanabat
# Processing Record 39 of Set 10 | kungurtug
# Processing Record 40 of Set 10 | cabedelo
# Processing Record 41 of Set 10 | loa janan
# Processing Record 42 of Set 10 | kem
# Processing Record 43 of Set 10 | tangzhai
# Processing Record 44 of Set 10 | fairview
# Processing Record 45 of Set 10 | manjacaze
# Processing Record 46 of Set 10 | onokhoy
# Processing Record 47 of Set 10 | trat
# Processing Record 48 of Set 10 | san fernando
# Processing Record 49 of Set 10 | yashkul
# Processing Record 50 of Set 10 | dakar
# Processing Record 1 of Set 11 | pacific grove
# Processing Record 2 of Set 11 | klyuchi
# Processing Record 3 of Set 11 | price
# Processing Record 4 of Set 11 | rio gallegos
# Processing Record 5 of Set 11 | umba
# Processing Record 6 of Set 11 | bend
# Processing Record 7 of Set 11 | alausi
# Processing Record 8 of Set 11 | mandurah
# Processing Record 9 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 10 of Set 11 | ostashkov
# Processing Record 11 of Set 11 | oussouye
# Processing Record 12 of Set 11 | mumford
# Processing Record 13 of Set 11 | nizhneangarsk
# Processing Record 14 of Set 11 | padang
# Processing Record 15 of Set 11 | egvekinot
# Processing Record 16 of Set 11 | wainwright
# Processing Record 17 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 11 | marang
# Processing Record 19 of Set 11 | meulaboh
# Processing Record 20 of Set 11 | dokshukino
# City not found. Skipping...
# Processing Record 21 of Set 11 | yellowknife
# Processing Record 22 of Set 11 | otane
# Processing Record 23 of Set 11 | tezu
# Processing Record 24 of Set 11 | trail
# Processing Record 25 of Set 11 | igrim
# Processing Record 26 of Set 11 | rochester
# Processing Record 27 of Set 11 | pancol
# Processing Record 28 of Set 11 | port-gentil
# Processing Record 29 of Set 11 | pangnirtung
# Processing Record 30 of Set 11 | mecca
# Processing Record 31 of Set 11 | erenhot
# Processing Record 32 of Set 11 | taga
# Processing Record 33 of Set 11 | palmer
# Processing Record 34 of Set 11 | huarmey
# Processing Record 35 of Set 11 | gweru
# Processing Record 36 of Set 11 | autun
# Processing Record 37 of Set 11 | razdolinsk
# Processing Record 38 of Set 11 | isabela
# Processing Record 39 of Set 11 | viamao
# Processing Record 40 of Set 11 | makubetsu
# Processing Record 41 of Set 11 | kysyl-syr
# Processing Record 42 of Set 11 | sabirabad
# Processing Record 43 of Set 11 | bagdarin
# Processing Record 44 of Set 11 | kargapolye
# City not found. Skipping...
# Processing Record 45 of Set 11 | zima
# Processing Record 46 of Set 11 | kaeo
# Processing Record 47 of Set 11 | kiruna
# Processing Record 48 of Set 11 | gazojak
# Processing Record 49 of Set 11 | agapovka
# Processing Record 50 of Set 11 | nhulunbuy
# Processing Record 1 of Set 12 | kogon
# Processing Record 2 of Set 12 | lakatoro
# Processing Record 3 of Set 12 | diourbel
# Processing Record 4 of Set 12 | magaria
# Processing Record 5 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 6 of Set 12 | fort-shevchenko
# Processing Record 7 of Set 12 | sili
# Processing Record 8 of Set 12 | aksarka
# Processing Record 9 of Set 12 | tessalit
# Processing Record 10 of Set 12 | pilar do sul
# Processing Record 11 of Set 12 | aybak
# City not found. Skipping...
# Processing Record 12 of Set 12 | namibe
# Processing Record 13 of Set 12 | katsuura
# Processing Record 14 of Set 12 | staromyshastovskaya
# Processing Record 15 of Set 12 | pingdu
# Processing Record 16 of Set 12 | brae
# Processing Record 17 of Set 12 | iranshahr
# Processing Record 18 of Set 12 | gat
# Processing Record 19 of Set 12 | ancud
# Processing Record 20 of Set 12 | mahajanga
# Processing Record 21 of Set 12 | puerto del rosario
# Processing Record 22 of Set 12 | talara
# Processing Record 23 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 24 of Set 12 | aracruz
# Processing Record 25 of Set 12 | olafsvik
# Processing Record 26 of Set 12 | takaka
# Processing Record 27 of Set 12 | pangai
# Processing Record 28 of Set 12 | ivanava
# Processing Record 29 of Set 12 | halifax
# Processing Record 30 of Set 12 | pizhanka
# Processing Record 31 of Set 12 | bronnoysund
# Processing Record 32 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 12 | lulea
# Processing Record 34 of Set 12 | aranos
# Processing Record 35 of Set 12 | kallithea
# Processing Record 36 of Set 12 | adiake
# Processing Record 37 of Set 12 | sembe
# Processing Record 38 of Set 12 | chara
# Processing Record 39 of Set 12 | najran
# Processing Record 40 of Set 12 | kaduqli
# Processing Record 41 of Set 12 | nkan
# Processing Record 42 of Set 12 | ponta delgada
# Processing Record 43 of Set 12 | maragogi
# Processing Record 44 of Set 12 | los llanos de aridane
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 12 | korla
# Processing Record 48 of Set 12 | talnakh
# Processing Record 49 of Set 12 | puerto colombia
# Processing Record 50 of Set 12 | aasiaat
# Processing Record 1 of Set 13 | namatanai
# Processing Record 2 of Set 13 | ciras
# City not found. Skipping...
# Processing Record 3 of Set 13 | gravdal
# Processing Record 4 of Set 13 | sosnovo-ozerskoye
# Processing Record 5 of Set 13 | piacabucu
# Processing Record 6 of Set 13 | kushima
# Processing Record 7 of Set 13 | qaqortoq
# Processing Record 8 of Set 13 | balaipungut
# Processing Record 9 of Set 13 | berlevag
# Processing Record 10 of Set 13 | ahipara
# Processing Record 11 of Set 13 | barrhead
# Processing Record 12 of Set 13 | masyaf
# Processing Record 13 of Set 13 | rathdrum
# Processing Record 14 of Set 13 | chernyshevskiy
# Processing Record 15 of Set 13 | charters towers
# Processing Record 16 of Set 13 | zunyi
# Processing Record 17 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 19 of Set 13 | libreville
# Processing Record 20 of Set 13 | araouane
# Processing Record 21 of Set 13 | muroto
# Processing Record 22 of Set 13 | san ramon
# Processing Record 23 of Set 13 | itarema
# Processing Record 24 of Set 13 | poroshkovo
# Processing Record 25 of Set 13 | morro bay
# Processing Record 26 of Set 13 | adrar
# Processing Record 27 of Set 13 | eskasem
# City not found. Skipping...
# Processing Record 28 of Set 13 | alekseyevsk
# Processing Record 29 of Set 13 | hovd
# Processing Record 30 of Set 13 | lata
# Processing Record 31 of Set 13 | kalmunai
# Processing Record 32 of Set 13 | touros
# Processing Record 33 of Set 13 | colonial heights
# Processing Record 34 of Set 13 | molochnoye
# Processing Record 35 of Set 13 | bani
# Processing Record 36 of Set 13 | parabel
# Processing Record 37 of Set 13 | dana point
# Processing Record 38 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 13 | marrakesh
# Processing Record 41 of Set 13 | shenjiamen
# Processing Record 42 of Set 13 | leshukonskoye
# Processing Record 43 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 13 | makasar
# Processing Record 45 of Set 13 | tefe
# Processing Record 46 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 13 | kochubey
# Processing Record 48 of Set 13 | nioro
# Processing Record 49 of Set 13 | louga
# Processing Record 50 of Set 13 | filadelfia
# Processing Record 1 of Set 14 | impfondo
# Processing Record 2 of Set 14 | balsas
# Processing Record 3 of Set 14 | concepcion
# Processing Record 4 of Set 14 | rawson
# Processing Record 5 of Set 14 | biltine
# Processing Record 6 of Set 14 | seoul
# Processing Record 7 of Set 14 | meiganga
# Processing Record 8 of Set 14 | kashihara
# Processing Record 9 of Set 14 | grootfontein
# Processing Record 10 of Set 14 | lexington
# Processing Record 11 of Set 14 | tupik
# Processing Record 12 of Set 14 | plettenberg bay
# Processing Record 13 of Set 14 | ayios matthaios
# City not found. Skipping...
# Processing Record 14 of Set 14 | tokur
# Processing Record 15 of Set 14 | esfarayen
# Processing Record 16 of Set 14 | miles city
# Processing Record 17 of Set 14 | port hedland
# Processing Record 18 of Set 14 | korem
# Processing Record 19 of Set 14 | nanakuli
# Processing Record 20 of Set 14 | comodoro rivadavia
# Processing Record 21 of Set 14 | masaka
# Processing Record 22 of Set 14 | tabou
# Processing Record 23 of Set 14 | zhuhai
# Processing Record 24 of Set 14 | koboldo
# City not found. Skipping...
# Processing Record 25 of Set 14 | vostok
# Processing Record 26 of Set 14 | kennett
# Processing Record 27 of Set 14 | puerto carreno
# Processing Record 28 of Set 14 | atasu
# Processing Record 29 of Set 14 | qeshm
# Processing Record 30 of Set 14 | forestville
# Processing Record 31 of Set 14 | gunjur
# Processing Record 32 of Set 14 | la union
# Processing Record 33 of Set 14 | negara
# Processing Record 34 of Set 14 | taloqan
# Processing Record 35 of Set 14 | kasongo-lunda
# Processing Record 36 of Set 14 | ketchikan
# Processing Record 37 of Set 14 | kapoeta
# Processing Record 38 of Set 14 | murupara
# Processing Record 39 of Set 14 | maumere
# Processing Record 40 of Set 14 | mata
# Processing Record 41 of Set 14 | jardim
# Processing Record 42 of Set 14 | krasnovishersk
# Processing Record 43 of Set 14 | durban
# Processing Record 44 of Set 14 | mo i rana
# Processing Record 45 of Set 14 | sena madureira
# Processing Record 46 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 14 | sanghar
# Processing Record 48 of Set 14 | ust-omchug
# Processing Record 49 of Set 14 | trinidad
# Processing Record 50 of Set 14 | mirabad
# Processing Record 1 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 15 | schladming
# Processing Record 3 of Set 15 | ormond beach
# Processing Record 4 of Set 15 | fochville
# Processing Record 5 of Set 15 | son la
# Processing Record 6 of Set 15 | turek
# Processing Record 7 of Set 15 | bereda
# Processing Record 8 of Set 15 | almeirim
# Processing Record 9 of Set 15 | anori
# Processing Record 10 of Set 15 | stanisic
# Processing Record 11 of Set 15 | anuchino
# Processing Record 12 of Set 15 | udachnyy
# Processing Record 13 of Set 15 | soyo
# Processing Record 14 of Set 15 | batsfjord
# Processing Record 15 of Set 15 | san andres
# Processing Record 16 of Set 15 | noyon
# Processing Record 17 of Set 15 | freeport
# Processing Record 18 of Set 15 | ferkessedougou
# Processing Record 19 of Set 15 | owensboro
# Processing Record 20 of Set 15 | faya
# Processing Record 21 of Set 15 | knysna
# Processing Record 22 of Set 15 | baykit
# Processing Record 23 of Set 15 | dauphin
# Processing Record 24 of Set 15 | cartagena
# Processing Record 25 of Set 15 | aquidauana
# Processing Record 26 of Set 15 | sept-iles
# Processing Record 27 of Set 15 | nyurba
# Processing Record 28 of Set 15 | ramnagar
# Processing Record 29 of Set 15 | okhotsk
# Processing Record 30 of Set 15 | hamadan
# Processing Record 31 of Set 15 | urumqi
# Processing Record 32 of Set 15 | sovetskiy
# Processing Record 33 of Set 15 | quilmana
# Processing Record 34 of Set 15 | cosenza
# Processing Record 35 of Set 15 | ituango
# Processing Record 36 of Set 15 | dolores
# Processing Record 37 of Set 15 | labuhan
# Processing Record 38 of Set 15 | svetlogorsk
# Processing Record 39 of Set 15 | gazli
# Processing Record 40 of Set 15 | lakes entrance
# Processing Record 41 of Set 15 | iseyin
# Processing Record 42 of Set 15 | olinda
# Processing Record 43 of Set 15 | ust-maya
# Processing Record 44 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 15 | ye
# City not found. Skipping...
# Processing Record 46 of Set 15 | guanare
# Processing Record 47 of Set 15 | insar
# Processing Record 48 of Set 15 | tazovskiy
# Processing Record 49 of Set 15 | diego de almagro
# Processing Record 50 of Set 15 | bundaberg
# Processing Record 1 of Set 16 | bahia honda
# Processing Record 2 of Set 16 | whyalla
# Processing Record 3 of Set 16 | beruwala
# Processing Record 4 of Set 16 | san rafael
# Processing Record 5 of Set 16 | sulurpeta
# City not found. Skipping...
# Processing Record 6 of Set 16 | porto velho
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'norman wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 3.2,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'port alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 64.62,
#   'Humidity': 82,
#   'Cloudiness': 26,
#   'Wind Speed': 17.25,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'puerto ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 69.01,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 55.99,
#   'Humidity': 61,
#   'Cloudiness': 48,
#   'Wind Speed': 10,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 61.47,
#   'Humidity': 64,
#   'Cloudiness': 2,
#   'Wind Speed': 6.08,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 81,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'barcelos',
#   'Lat': 41.54,
#   'Lng': -8.62,
#   'Max Temp': 64.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'PT',
#   'Current Description': 'mist',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 13.87,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:37:58'},
#  {'City': 'sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 25.28,
#   'Country': 'US',
#   'Current Description': 'heavy intensity rain',
#   'Date': '2020-11-02 02:42:34'},
#  {'City': 'lamar',
#   'Lat': 33.67,
#   'Lng': -95.58,
#   'Max Temp': 50,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 23,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'GL',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Country': 'TO',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'saint george',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 66.2,
#   'Humidity': 14,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:46:04'},
#  {'City': 'aguimes',
#   'Lat': 27.91,
#   'Lng': -15.45,
#   'Max Temp': 71.6,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'ES',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.85,
#   'Humidity': 86,
#   'Cloudiness': 91,
#   'Wind Speed': 24.32,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:46:33'},
#  {'City': 'cabo san lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 79,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'camocim',
#   'Lat': -2.9,
#   'Lng': -40.84,
#   'Max Temp': 77.92,
#   'Humidity': 86,
#   'Cloudiness': 64,
#   'Wind Speed': 8.84,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 93,
#   'Wind Speed': 17.22,
#   'Country': 'CK',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'kisangani',
#   'Lat': 0.52,
#   'Lng': 25.2,
#   'Max Temp': 69.6,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.5,
#   'Country': 'CD',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 3,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 6.51,
#   'Country': 'GL',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:58'},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 51.8,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:59'},
#  {'City': 'saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': -7.29,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 10.51,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:50:59'},
#  {'City': 'deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -14.17,
#   'Humidity': 88,
#   'Cloudiness': 38,
#   'Wind Speed': 5.88,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:50:59'},
#  {'City': 'ust-tarka',
#   'Lat': 55.57,
#   'Lng': 75.7,
#   'Max Temp': 33.17,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.13,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:50:51'},
#  {'City': 'bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 46.4,
#   'Humidity': 61,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:47:14'},
#  {'City': 'roald',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 51.8,
#   'Humidity': 57,
#   'Cloudiness': 69,
#   'Wind Speed': 11.41,
#   'Country': 'NO',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:46:44'},
#  {'City': 'nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:50:59'},
#  {'City': 'new norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 81,
#   'Humidity': 23,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:46:34'},
#  {'City': 'carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 73.4,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:50:59'},
#  {'City': 'jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 35.01,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 18.34,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:50:59'},
#  {'City': 'ribeira grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 62.73,
#   'Humidity': 75,
#   'Cloudiness': 38,
#   'Wind Speed': 18.81,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'talas',
#   'Lat': 38.69,
#   'Lng': 35.55,
#   'Max Temp': 42.8,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'TR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'middelburg',
#   'Lat': -25.78,
#   'Lng': 29.46,
#   'Max Temp': 55.92,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 3.09,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'bilma',
#   'Lat': 18.69,
#   'Lng': 12.92,
#   'Max Temp': 66.97,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 11.56,
#   'Country': 'NE',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 50.34,
#   'Humidity': 92,
#   'Cloudiness': 41,
#   'Wind Speed': 10.29,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:46:39'},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 57.2,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'AR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'mindelo',
#   'Lat': 16.89,
#   'Lng': -24.98,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'CV',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'port-cartier',
#   'Lat': 50.03,
#   'Lng': -66.87,
#   'Max Temp': 39.2,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 21.2,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 6.42,
#   'Country': 'CA',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:01'},
#  {'City': 'shihezi',
#   'Lat': 44.3,
#   'Lng': 86.03,
#   'Max Temp': 43.48,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 0.4,
#   'Country': 'CN',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:01'},
#  {'City': 'cape town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 62.6,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:01'},
#  {'City': 'tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 76.64,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 1.77,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:01'},
#  {'City': 'faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 79.97,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 18.32,
#   'Country': 'PF',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:01'},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 77.45,
#   'Humidity': 79,
#   'Cloudiness': 79,
#   'Wind Speed': 13.65,
#   'Country': 'PF',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:01'},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 60.01,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 4.83,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:46:37'},
#  {'City': 'oriximina',
#   'Lat': -1.77,
#   'Lng': -55.87,
#   'Max Temp': 81.18,
#   'Humidity': 65,
#   'Cloudiness': 89,
#   'Wind Speed': 4.12,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:02'},
#  {'City': 'albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 41,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:47:56'},
#  {'City': 'cayenne',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 99,
#   'Wind Speed': 3.36,
#   'Country': 'GF',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:02'},
#  {'City': 'ekhabi',
#   'Lat': 53.51,
#   'Lng': 142.97,
#   'Max Temp': 44.76,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 13.69,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:02'},
#  {'City': 'tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 55.99,
#   'Humidity': 65,
#   'Cloudiness': 16,
#   'Wind Speed': 11.99,
#   'Country': 'NZ',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:50:07'},
#  {'City': 'basco',
#   'Lat': 20.45,
#   'Lng': 121.97,
#   'Max Temp': 79.86,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 28.86,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:02'},
#  {'City': 'hualmay',
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 60.87,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 8.3,
#   'Country': 'PE',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:02'},
#  {'City': 'east london',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 64.13,
#   'Humidity': 83,
#   'Cloudiness': 34,
#   'Wind Speed': 15.79,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:02'},
#  {'City': 'ardmore',
#   'Lat': 34.17,
#   'Lng': -97.14,
#   'Max Temp': 54,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 4.85,
#   'Country': 'US',
#   'Current Description': 'haze',
#   'Date': '2020-11-02 02:47:04'},
#  {'City': 'nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 21.92,
#   'Country': 'JP',
#   'Current Description': 'light intensity shower rain',
#   'Date': '2020-11-02 02:51:02'},
#  {'City': 'grand gaube',
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 71.01,
#   'Humidity': 65,
#   'Cloudiness': 63,
#   'Wind Speed': 1.99,
#   'Country': 'MU',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:46:56'},
#  {'City': 'lebowakgomo',
#   'Lat': -24.2,
#   'Lng': 29.5,
#   'Max Temp': 57.2,
#   'Humidity': 93,
#   'Cloudiness': 67,
#   'Wind Speed': 5.82,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:03'},
#  {'City': 'veraval',
#   'Lat': 20.9,
#   'Lng': 70.37,
#   'Max Temp': 81.3,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 13.42,
#   'Country': 'IN',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:03'},
#  {'City': 'rosarito',
#   'Lat': 32.33,
#   'Lng': -117.03,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 5.55,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:03'},
#  {'City': 'surt',
#   'Lat': 31.21,
#   'Lng': 16.59,
#   'Max Temp': 69.03,
#   'Humidity': 62,
#   'Cloudiness': 2,
#   'Wind Speed': 6.67,
#   'Country': 'LY',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:03'},
#  {'City': 'hobyo',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 79.81,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 6.17,
#   'Country': 'SO',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'vallenar',
#   'Lat': -28.57,
#   'Lng': -70.76,
#   'Max Temp': 54.95,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 1.14,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 31,
#   'Wind Speed': 14.99,
#   'Country': 'FO',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'praia da vitoria',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 15.68,
#   'Country': 'PT',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'kaoma',
#   'Lat': -14.78,
#   'Lng': 24.8,
#   'Max Temp': 64.65,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 7.67,
#   'Country': 'ZM',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'hit',
#   'Lat': 33.64,
#   'Lng': 42.83,
#   'Max Temp': 68.63,
#   'Humidity': 25,
#   'Cloudiness': 90,
#   'Wind Speed': 10.16,
#   'Country': 'IQ',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Cloudiness': 91,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 54,
#   'Humidity': 59,
#   'Cloudiness': 91,
#   'Wind Speed': 8.01,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:04'},
#  {'City': 'hudson bay',
#   'Lat': 52.85,
#   'Lng': -102.38,
#   'Max Temp': 36.7,
#   'Humidity': 89,
#   'Cloudiness': 93,
#   'Wind Speed': 9.06,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:05'},
#  {'City': 'kenai',
#   'Lat': 60.55,
#   'Lng': -151.26,
#   'Max Temp': 24.01,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 28.86,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:05'},
#  {'City': 'the valley',
#   'Lat': 18.22,
#   'Lng': -63.06,
#   'Max Temp': 82.99,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'AI',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:05'},
#  {'City': 'bintulu',
#   'Lat': 3.17,
#   'Lng': 113.03,
#   'Max Temp': 82.4,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'MY',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:05'},
#  {'City': 'moree',
#   'Lat': -29.47,
#   'Lng': 149.85,
#   'Max Temp': 82.4,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 11.86,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:05'},
#  {'City': 'saint-augustin',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 38.17,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 16.31,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:05'},
#  {'City': 'nadym',
#   'Lat': 65.53,
#   'Lng': 72.52,
#   'Max Temp': 23.95,
#   'Humidity': 97,
#   'Cloudiness': 87,
#   'Wind Speed': 15.77,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:05'},
#  {'City': 'longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 35.6,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 26.4,
#   'Country': 'SJ',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'north bay',
#   'Lat': 46.32,
#   'Lng': -79.47,
#   'Max Temp': 30.99,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 26.4,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:00'},
#  {'City': 'panguna',
#   'Lat': -6.32,
#   'Lng': 155.48,
#   'Max Temp': 81.28,
#   'Humidity': 69,
#   'Cloudiness': 29,
#   'Wind Speed': 1.05,
#   'Country': 'PG',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 38.89,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 25.37,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'sao filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 78.51,
#   'Humidity': 78,
#   'Cloudiness': 94,
#   'Wind Speed': 5.84,
#   'Country': 'CV',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 74.7,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 14.76,
#   'Country': 'NC',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 53.28,
#   'Humidity': 94,
#   'Cloudiness': 82,
#   'Wind Speed': 7.65,
#   'Country': 'CL',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'muli',
#   'Lat': 2.92,
#   'Lng': 73.57,
#   'Max Temp': 82.33,
#   'Humidity': 71,
#   'Cloudiness': 20,
#   'Wind Speed': 5.39,
#   'Country': 'MV',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'arraial do cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 68.43,
#   'Humidity': 71,
#   'Cloudiness': 4,
#   'Wind Speed': 16.91,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:06'},
#  {'City': 'takoradi',
#   'Lat': 4.88,
#   'Lng': -1.76,
#   'Max Temp': 77.36,
#   'Humidity': 90,
#   'Cloudiness': 67,
#   'Wind Speed': 5.79,
#   'Country': 'GH',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:07'},
#  {'City': 'santiago del estero',
#   'Lat': -27.8,
#   'Lng': -64.26,
#   'Max Temp': 69.1,
#   'Humidity': 37,
#   'Cloudiness': 55,
#   'Wind Speed': 8.37,
#   'Country': 'AR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:07'},
#  {'City': 'grindavik',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'IS',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:07'},
#  {'City': 'coihaique',
#   'Lat': -45.58,
#   'Lng': -72.07,
#   'Max Temp': 55.4,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:07'},
#  {'City': 'geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'AU',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:07'},
#  {'City': 'kompaniyivka',
#   'Lat': 48.25,
#   'Lng': 32.21,
#   'Max Temp': 45.88,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 11.79,
#   'Country': 'UA',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:07'},
#  {'City': 'mar del plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 60.01,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:48:15'},
#  {'City': 'pilar',
#   'Lat': -9.6,
#   'Lng': -35.96,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'kupang',
#   'Lat': -10.17,
#   'Lng': 123.58,
#   'Max Temp': 88.72,
#   'Humidity': 52,
#   'Cloudiness': 41,
#   'Wind Speed': 2.68,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'shimoda',
#   'Lat': 34.67,
#   'Lng': 138.95,
#   'Max Temp': 69.8,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'JP',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 55,
#   'Wind Speed': 14.99,
#   'Country': 'NU',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'san quintin',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 66.31,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 5.26,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'hellin',
#   'Lat': 38.51,
#   'Lng': -1.7,
#   'Max Temp': 56.46,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 1.79,
#   'Country': 'ES',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 26.6,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 19.46,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'alice springs',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 91.4,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:49:15'},
#  {'City': 'khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 6.57,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.73,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:08'},
#  {'City': 'arlit',
#   'Lat': 18.74,
#   'Lng': 7.39,
#   'Max Temp': 69.3,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Country': 'NE',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 24.8,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'GL',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'bat yam',
#   'Lat': 32.02,
#   'Lng': 34.75,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'IL',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'bambous virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 71.01,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'maceio',
#   'Lat': -9.67,
#   'Lng': -35.74,
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'khasan',
#   'Lat': 42.43,
#   'Lng': 130.64,
#   'Max Temp': 47.97,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 15.19,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'teguise',
#   'Lat': 29.06,
#   'Lng': -13.56,
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'ES',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 55.99,
#   'Humidity': 65,
#   'Cloudiness': 53,
#   'Wind Speed': 11.99,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:09'},
#  {'City': 'hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 37.99,
#   'Humidity': 44,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:48:42'},
#  {'City': 'tilichiki',
#   'Lat': 60.47,
#   'Lng': 166.1,
#   'Max Temp': 29.53,
#   'Humidity': 94,
#   'Cloudiness': 84,
#   'Wind Speed': 3.09,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:10'},
#  {'City': 'coari',
#   'Lat': -4.08,
#   'Lng': -63.14,
#   'Max Temp': 76.57,
#   'Humidity': 79,
#   'Cloudiness': 67,
#   'Wind Speed': 2.66,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:49:25'},
#  {'City': 'erzin',
#   'Lat': 36.96,
#   'Lng': 36.2,
#   'Max Temp': 66.99,
#   'Humidity': 70,
#   'Cloudiness': 65,
#   'Wind Speed': 4,
#   'Country': 'TR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:10'},
#  {'City': 'pacifica',
#   'Lat': 37.61,
#   'Lng': -122.49,
#   'Max Temp': 66,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:10'},
#  {'City': 'ahuimanu',
#   'Lat': 21.44,
#   'Lng': -157.84,
#   'Max Temp': 80.6,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:10'},
#  {'City': 'lafia',
#   'Lat': 8.48,
#   'Lng': 8.52,
#   'Max Temp': 74.12,
#   'Humidity': 68,
#   'Cloudiness': 91,
#   'Wind Speed': 1.95,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:10'},
#  {'City': 'mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 64.4,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:47:34'},
#  {'City': 'ossora',
#   'Lat': 59.24,
#   'Lng': 163.07,
#   'Max Temp': 34.72,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:10'},
#  {'City': 'bwanga',
#   'Lat': -3.03,
#   'Lng': 31.76,
#   'Max Temp': 65.53,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'TZ',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:10'},
#  {'City': 'port elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 62.6,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'amherstburg',
#   'Lat': 42.12,
#   'Lng': -83.05,
#   'Max Temp': 35.6,
#   'Humidity': 55,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 64.4,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'MU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'laguna',
#   'Lat': 38.42,
#   'Lng': -121.42,
#   'Max Temp': 68,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 3.02,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'bonthe',
#   'Lat': 7.53,
#   'Lng': -12.51,
#   'Max Temp': 77.92,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind Speed': 6.8,
#   'Country': 'SL',
#   'Current Description': 'moderate rain',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 12.2,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Current Description': 'light snow',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'hukuntsi',
#   'Lat': -24,
#   'Lng': 21.75,
#   'Max Temp': 71.08,
#   'Humidity': 53,
#   'Cloudiness': 36,
#   'Wind Speed': 10.13,
#   'Country': 'BW',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'aripuana',
#   'Lat': -9.17,
#   'Lng': -60.63,
#   'Max Temp': 70.77,
#   'Humidity': 98,
#   'Cloudiness': 96,
#   'Wind Speed': 1.54,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:49:01'},
#  {'City': 'coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:11'},
#  {'City': 'wattegama',
#   'Lat': 6.8,
#   'Lng': 81.48,
#   'Max Temp': 82.38,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 1.07,
#   'Country': 'LK',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'maltahohe',
#   'Lat': -24.83,
#   'Lng': 16.98,
#   'Max Temp': 64.54,
#   'Humidity': 26,
#   'Cloudiness': 41,
#   'Wind Speed': 8.37,
#   'Country': 'NA',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'carutapera',
#   'Lat': -1.2,
#   'Lng': -46.02,
#   'Max Temp': 77.88,
#   'Humidity': 84,
#   'Cloudiness': 25,
#   'Wind Speed': 5.66,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'suamico',
#   'Lat': 44.63,
#   'Lng': -88.04,
#   'Max Temp': 28.4,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 52.21,
#   'Humidity': 86,
#   'Cloudiness': 5,
#   'Wind Speed': 3.53,
#   'Country': 'UY',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 15.8,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Current Description': 'light snow',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'saint anthony',
#   'Lat': 45.02,
#   'Lng': -93.22,
#   'Max Temp': 32,
#   'Humidity': 58,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'MY',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:48:42'},
#  {'City': 'carauari',
#   'Lat': -4.88,
#   'Lng': -66.9,
#   'Max Temp': 72.91,
#   'Humidity': 93,
#   'Cloudiness': 30,
#   'Wind Speed': 2.01,
#   'Country': 'BR',
#   'Current Description': 'moderate rain',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'sao joao da barra',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 67.12,
#   'Humidity': 80,
#   'Cloudiness': 85,
#   'Wind Speed': 18.39,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:12'},
#  {'City': 'emerald',
#   'Lat': -23.53,
#   'Lng': 148.17,
#   'Max Temp': 91.99,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:13'},
#  {'City': 'da nang',
#   'Lat': 16.07,
#   'Lng': 108.22,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'VN',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:13'},
#  {'City': 'codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 74.89,
#   'Humidity': 62,
#   'Cloudiness': 4,
#   'Wind Speed': 10.76,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:46:46'},
#  {'City': 'esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'AU',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:13'},
#  {'City': 'mount gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 80.6,
#   'Humidity': 32,
#   'Cloudiness': 43,
#   'Wind Speed': 14.99,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:13'},
#  {'City': 'muros',
#   'Lat': 42.78,
#   'Lng': -9.06,
#   'Max Temp': 66.99,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'ES',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:13'},
#  {'City': 'patacamaya',
#   'Lat': -17.23,
#   'Lng': -67.92,
#   'Max Temp': 43.97,
#   'Humidity': 76,
#   'Cloudiness': 70,
#   'Wind Speed': 9.31,
#   'Country': 'BO',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:13'},
#  {'City': 'smithers',
#   'Lat': 54.78,
#   'Lng': -127.17,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'CA',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:13'},
#  {'City': 'hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'manitouwadge',
#   'Lat': 49.12,
#   'Lng': -85.84,
#   'Max Temp': 21.2,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 1.12,
#   'Country': 'CA',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'college',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': -0.99,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.21,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 71.6,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'OM',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'kanniyakumari',
#   'Lat': 8.08,
#   'Lng': 77.57,
#   'Max Temp': 81.88,
#   'Humidity': 70,
#   'Cloudiness': 42,
#   'Wind Speed': 7.07,
#   'Country': 'IN',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'kholodnyy',
#   'Lat': 62.72,
#   'Lng': 147.95,
#   'Max Temp': 4.21,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 2.91,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'altay',
#   'Lat': 47.87,
#   'Lng': 88.12,
#   'Max Temp': 37.74,
#   'Humidity': 61,
#   'Cloudiness': 54,
#   'Wind Speed': 2.19,
#   'Country': 'CN',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'takhtamygda',
#   'Lat': 54.1,
#   'Lng': 123.57,
#   'Max Temp': 12.18,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 12.86,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 86.76,
#   'Humidity': 62,
#   'Cloudiness': 76,
#   'Wind Speed': 6.71,
#   'Country': 'PG',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:14'},
#  {'City': 'bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 23.04,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:46:45'},
#  {'City': 'boden',
#   'Lat': 65.83,
#   'Lng': 21.69,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 23.04,
#   'Country': 'SE',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:15'},
#  {'City': 'samarai',
#   'Lat': -10.62,
#   'Lng': 150.67,
#   'Max Temp': 83.84,
#   'Humidity': 74,
#   'Cloudiness': 59,
#   'Wind Speed': 10.8,
#   'Country': 'PG',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:15'},
#  {'City': 'tatvan',
#   'Lat': 38.51,
#   'Lng': 42.28,
#   'Max Temp': 43.48,
#   'Humidity': 75,
#   'Cloudiness': 99,
#   'Wind Speed': 2.57,
#   'Country': 'TR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:15'},
#  {'City': 'half moon bay',
#   'Lat': 37.46,
#   'Lng': -122.43,
#   'Max Temp': 68,
#   'Humidity': 52,
#   'Cloudiness': 5,
#   'Wind Speed': 5.32,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:46:37'},
#  {'City': 'lobito',
#   'Lat': -12.35,
#   'Lng': 13.55,
#   'Max Temp': 75.85,
#   'Humidity': 87,
#   'Cloudiness': 35,
#   'Wind Speed': 4.05,
#   'Country': 'AO',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:15'},
#  {'City': 'enumclaw',
#   'Lat': 47.2,
#   'Lng': -121.99,
#   'Max Temp': 50,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 3.8,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:15'},
#  {'City': 'kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:46:37'},
#  {'City': 'camacha',
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 66.2,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4.27,
#   'Country': 'PT',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:15'},
#  {'City': 'pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 13.98,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 8.39,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:46:48'},
#  {'City': 'tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': -5.66,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 6.15,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'liverpool',
#   'Lat': 53.41,
#   'Lng': -2.98,
#   'Max Temp': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 25.28,
#   'Country': 'GB',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'mayskiy',
#   'Lat': 47.69,
#   'Lng': 40.1,
#   'Max Temp': 53.6,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'te anau',
#   'Lat': -45.42,
#   'Lng': 167.72,
#   'Max Temp': 60.31,
#   'Humidity': 39,
#   'Cloudiness': 14,
#   'Wind Speed': 1.9,
#   'Country': 'NZ',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'hunchun',
#   'Lat': 42.87,
#   'Lng': 130.36,
#   'Max Temp': 46.35,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 12.28,
#   'Country': 'CN',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'dunedin',
#   'Lat': -45.87,
#   'Lng': 170.5,
#   'Max Temp': 55,
#   'Humidity': 65,
#   'Cloudiness': 36,
#   'Wind Speed': 15.99,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'clyde river',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 8.6,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'dodge city',
#   'Lat': 37.75,
#   'Lng': -100.02,
#   'Max Temp': 48.2,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:46:24'},
#  {'City': 'lagoa',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 61.84,
#   'Humidity': 70,
#   'Cloudiness': 44,
#   'Wind Speed': 17.34,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'kawalu',
#   'Lat': -7.38,
#   'Lng': 108.21,
#   'Max Temp': 82.49,
#   'Humidity': 67,
#   'Cloudiness': 91,
#   'Wind Speed': 5.73,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:16'},
#  {'City': 'nortelandia',
#   'Lat': -14.45,
#   'Lng': -56.8,
#   'Max Temp': 78.44,
#   'Humidity': 61,
#   'Cloudiness': 94,
#   'Wind Speed': 0.29,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'san jose',
#   'Lat': 37.34,
#   'Lng': -121.89,
#   'Max Temp': 66,
#   'Humidity': 56,
#   'Cloudiness': 41,
#   'Wind Speed': 0.58,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:47:29'},
#  {'City': 'oistins',
#   'Lat': 13.07,
#   'Lng': -59.53,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 23.04,
#   'Country': 'BB',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'sisimiut',
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Max Temp': 27.48,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 9.62,
#   'Country': 'GL',
#   'Current Description': 'light snow',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'saint-philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 69.8,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'RE',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 86.25,
#   'Humidity': 64,
#   'Cloudiness': 9,
#   'Wind Speed': 1.54,
#   'Country': 'PG',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 18.46,
#   'Humidity': 98,
#   'Cloudiness': 89,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:46:37'},
#  {'City': 'camopi',
#   'Lat': 3.17,
#   'Lng': -52.32,
#   'Max Temp': 73.49,
#   'Humidity': 95,
#   'Cloudiness': 14,
#   'Wind Speed': 2.28,
#   'Country': 'GF',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -1.43,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.73,
#   'Country': 'RU',
#   'Current Description': 'light snow',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'morehead',
#   'Lat': 37.27,
#   'Lng': -87.18,
#   'Max Temp': 42.8,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:17'},
#  {'City': 'upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 16.57,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind Speed': 4,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'dubbo',
#   'Lat': -32.25,
#   'Lng': 148.62,
#   'Max Temp': 75.2,
#   'Humidity': 38,
#   'Cloudiness': 47,
#   'Wind Speed': 10.29,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:50:10'},
#  {'City': 'puerto quijarro',
#   'Lat': -17.78,
#   'Lng': -57.77,
#   'Max Temp': 74.46,
#   'Humidity': 55,
#   'Cloudiness': 32,
#   'Wind Speed': 3.44,
#   'Country': 'BO',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'urusha',
#   'Lat': 54.05,
#   'Lng': 122.9,
#   'Max Temp': 11.19,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.87,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'kasempa',
#   'Lat': -13.46,
#   'Lng': 25.83,
#   'Max Temp': 65.62,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.57,
#   'Country': 'ZM',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'kihei',
#   'Lat': 20.79,
#   'Lng': -156.47,
#   'Max Temp': 84.2,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:47:57'},
#  {'City': 'moron',
#   'Lat': -34.65,
#   'Lng': -58.62,
#   'Max Temp': 66.99,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'birin',
#   'Lat': 26.89,
#   'Lng': 88.07,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'NP',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'riyadh',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 59,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 4.16,
#   'Country': 'SA',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:44'},
#  {'City': 'abalak',
#   'Lat': 58.13,
#   'Lng': 68.59,
#   'Max Temp': 25.57,
#   'Humidity': 99,
#   'Cloudiness': 45,
#   'Wind Speed': 5.48,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 26.6,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:18'},
#  {'City': 'baghdad',
#   'Lat': 33.34,
#   'Lng': 44.4,
#   'Max Temp': 69.8,
#   'Humidity': 37,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'IQ',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 35.8,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 14.7,
#   'Country': 'IS',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'isangel',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'VU',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'ozinki',
#   'Lat': 51.18,
#   'Lng': 49.68,
#   'Max Temp': 40.75,
#   'Humidity': 71,
#   'Cloudiness': 31,
#   'Wind Speed': 8.23,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'irece',
#   'Lat': -11.3,
#   'Lng': -41.86,
#   'Max Temp': 70.47,
#   'Humidity': 86,
#   'Cloudiness': 66,
#   'Wind Speed': 4.52,
#   'Country': 'BR',
#   'Current Description': 'light rain',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'oksfjord',
#   'Lat': 70.24,
#   'Lng': 22.35,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 98,
#   'Wind Speed': 27.51,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'diamantino',
#   'Lat': -14.41,
#   'Lng': -56.45,
#   'Max Temp': 77.5,
#   'Humidity': 71,
#   'Cloudiness': 77,
#   'Wind Speed': 3.06,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'axim',
#   'Lat': 4.87,
#   'Lng': -2.24,
#   'Max Temp': 77.47,
#   'Humidity': 89,
#   'Cloudiness': 14,
#   'Wind Speed': 6.33,
#   'Country': 'GH',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:51:19'},
#  {'City': 'caravelas',
#   'Lat': -17.71,
#   'Lng': -39.25,
#   'Max Temp': 71.47,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.33,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:20'},
#  {'City': 'mosquera',
#   'Lat': 4.71,
#   'Lng': -74.23,
#   'Max Temp': 57.2,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'CO',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:51:20'},
#  {'City': 'channel-port aux basques',
#   'Lat': 47.57,
#   'Lng': -59.14,
#   'Max Temp': 45.27,
#   'Humidity': 82,
#   'Cloudiness': 93,
#   'Wind Speed': 17.18,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:20'},
#  {'City': 'canutama',
#   'Lat': -6.53,
#   'Lng': -64.38,
#   'Max Temp': 75.52,
#   'Humidity': 91,
#   'Cloudiness': 85,
#   'Wind Speed': 1.05,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:51:20'},
#  {'City': 'ponta do sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 66.99,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:20'},
#  {'City': 'tenenkou',
#   'Lat': 14.46,
#   'Lng': -4.92,
#   'Max Temp': 78.35,
#   'Humidity': 17,
#   'Cloudiness': 6,
#   'Wind Speed': 7.85,
#   'Country': 'ML',
#   'Current Description': 'clear sky',
# ...
#   'Humidity': 82,
#   'Cloudiness': 89,
#   'Wind Speed': 9.78,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:11'},
#  {'City': 'negara',
#   'Lat': -8.32,
#   'Lng': 114.6,
#   'Max Temp': 85.8,
#   'Humidity': 63,
#   'Cloudiness': 33,
#   'Wind Speed': 3.49,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:49:14'},
#  {'City': 'taloqan',
#   'Lat': 36.74,
#   'Lng': 69.53,
#   'Max Temp': 52.47,
#   'Humidity': 33,
#   'Cloudiness': 64,
#   'Wind Speed': 2.17,
#   'Country': 'AF',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:12'},
#  {'City': 'kasongo-lunda',
#   'Lat': -6.47,
#   'Lng': 16.82,
#   'Max Temp': 69.89,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:12'},
#  {'City': 'ketchikan',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 51.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 51.67,
#   'Country': 'US',
#   'Current Description': 'heavy intensity rain',
#   'Date': '2020-11-02 02:52:12'},
#  {'City': 'kapoeta',
#   'Lat': 4.77,
#   'Lng': 33.59,
#   'Max Temp': 77.67,
#   'Humidity': 58,
#   'Cloudiness': 98,
#   'Wind Speed': 10.74,
#   'Country': 'SS',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:12'},
#  {'City': 'murupara',
#   'Lat': -38.47,
#   'Lng': 176.7,
#   'Max Temp': 77,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:12'},
#  {'City': 'maumere',
#   'Lat': -8.62,
#   'Lng': 122.21,
#   'Max Temp': 86.81,
#   'Humidity': 60,
#   'Cloudiness': 94,
#   'Wind Speed': 1.95,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:12'},
#  {'City': 'mata',
#   'Lat': 40.68,
#   'Lng': -7.46,
#   'Max Temp': 60.01,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 4.92,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:12'},
#  {'City': 'jardim',
#   'Lat': -21.48,
#   'Lng': -56.14,
#   'Max Temp': 68.31,
#   'Humidity': 71,
#   'Cloudiness': 11,
#   'Wind Speed': 3.71,
#   'Country': 'BR',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:52:13'},
#  {'City': 'krasnovishersk',
#   'Lat': 60.41,
#   'Lng': 57.08,
#   'Max Temp': 25.16,
#   'Humidity': 98,
#   'Cloudiness': 67,
#   'Wind Speed': 2.39,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:13'},
#  {'City': 'durban',
#   'Lat': -29.86,
#   'Lng': 31.03,
#   'Max Temp': 62.01,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'ZA',
#   'Current Description': 'heavy intensity rain',
#   'Date': '2020-11-02 02:47:50'},
#  {'City': 'mo i rana',
#   'Lat': 66.31,
#   'Lng': 14.14,
#   'Max Temp': 42.1,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 8.21,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:13'},
#  {'City': 'sena madureira',
#   'Lat': -9.07,
#   'Lng': -68.66,
#   'Max Temp': 73.74,
#   'Humidity': 75,
#   'Cloudiness': 10,
#   'Wind Speed': 1.39,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:13'},
#  {'City': 'sanghar',
#   'Lat': 26.05,
#   'Lng': 68.95,
#   'Max Temp': 79.21,
#   'Humidity': 17,
#   'Cloudiness': 0,
#   'Wind Speed': 0.78,
#   'Country': 'PK',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:14'},
#  {'City': 'ust-omchug',
#   'Lat': 61.15,
#   'Lng': 149.63,
#   'Max Temp': 25.93,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'RU',
#   'Current Description': 'light snow',
#   'Date': '2020-11-02 02:52:14'},
#  {'City': 'trinidad',
#   'Lat': -14.83,
#   'Lng': -64.9,
#   'Max Temp': 74.71,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Country': 'BO',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:14'},
#  {'City': 'mirabad',
#   'Lat': 30.44,
#   'Lng': 61.84,
#   'Max Temp': 53.98,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'AF',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:14'},
#  {'City': 'schladming',
#   'Lat': 47.39,
#   'Lng': 13.69,
#   'Max Temp': 53.6,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'AT',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:15'},
#  {'City': 'ormond beach',
#   'Lat': 29.29,
#   'Lng': -81.06,
#   'Max Temp': 72,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:49:35'},
#  {'City': 'fochville',
#   'Lat': -26.49,
#   'Lng': 27.49,
#   'Max Temp': 58.95,
#   'Humidity': 82,
#   'Cloudiness': 95,
#   'Wind Speed': 9.55,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:15'},
#  {'City': 'son la',
#   'Lat': 21.32,
#   'Lng': 103.9,
#   'Max Temp': 76.6,
#   'Humidity': 69,
#   'Cloudiness': 62,
#   'Wind Speed': 2.66,
#   'Country': 'VN',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:15'},
#  {'City': 'turek',
#   'Lat': 52.02,
#   'Lng': 18.5,
#   'Max Temp': 48,
#   'Humidity': 95,
#   'Cloudiness': 72,
#   'Wind Speed': 4,
#   'Country': 'PL',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:15'},
#  {'City': 'bereda',
#   'Lat': 43.27,
#   'Lng': -7.54,
#   'Max Temp': 66,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Country': 'ES',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:16'},
#  {'City': 'almeirim',
#   'Lat': -1.52,
#   'Lng': -52.58,
#   'Max Temp': 81.05,
#   'Humidity': 57,
#   'Cloudiness': 90,
#   'Wind Speed': 4.41,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:16'},
#  {'City': 'anori',
#   'Lat': -3.77,
#   'Lng': -61.64,
#   'Max Temp': 75.47,
#   'Humidity': 80,
#   'Cloudiness': 72,
#   'Wind Speed': 1.99,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:16'},
#  {'City': 'stanisic',
#   'Lat': 45.94,
#   'Lng': 19.17,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'RS',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:16'},
#  {'City': 'anuchino',
#   'Lat': 43.96,
#   'Lng': 133.05,
#   'Max Temp': 41.63,
#   'Humidity': 61,
#   'Cloudiness': 16,
#   'Wind Speed': 8.9,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:52:16'},
#  {'City': 'udachnyy',
#   'Lat': 66.42,
#   'Lng': 112.4,
#   'Max Temp': 8.6,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:16'},
#  {'City': 'soyo',
#   'Lat': -6.13,
#   'Lng': 12.37,
#   'Max Temp': 77.49,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.3,
#   'Country': 'AO',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:16'},
#  {'City': 'batsfjord',
#   'Lat': 70.63,
#   'Lng': 29.72,
#   'Max Temp': 42.53,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 31.99,
#   'Country': 'NO',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:17'},
#  {'City': 'san andres',
#   'Lat': 12.58,
#   'Lng': -81.7,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'CO',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:17'},
#  {'City': 'noyon',
#   'Lat': 49.58,
#   'Lng': 3,
#   'Max Temp': 64,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 23.04,
#   'Country': 'FR',
#   'Current Description': 'light intensity drizzle',
#   'Date': '2020-11-02 02:52:17'},
#  {'City': 'freeport',
#   'Lat': 40.66,
#   'Lng': -73.58,
#   'Max Temp': 51.01,
#   'Humidity': 70,
#   'Cloudiness': 88,
#   'Wind Speed': 10,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:17'},
#  {'City': 'ferkessedougou',
#   'Lat': 9.6,
#   'Lng': -5.2,
#   'Max Temp': 74.37,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 3.83,
#   'Country': 'CI',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:18'},
#  {'City': 'owensboro',
#   'Lat': 37.77,
#   'Lng': -87.11,
#   'Max Temp': 41,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:50:01'},
#  {'City': 'faya',
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 55.4,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 3.33,
#   'Country': 'SA',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:18'},
#  {'City': 'knysna',
#   'Lat': -34.04,
#   'Lng': 23.05,
#   'Max Temp': 55.4,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:18'},
#  {'City': 'baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 27.99,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.58,
#   'Country': 'RU',
#   'Current Description': 'light snow',
#   'Date': '2020-11-02 02:52:18'},
#  {'City': 'dauphin',
#   'Lat': 51.15,
#   'Lng': -100.05,
#   'Max Temp': 42.8,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 20.8,
#   'Country': 'CA',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:50:13'},
#  {'City': 'cartagena',
#   'Lat': 10.4,
#   'Lng': -75.51,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'CO',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:52:18'},
#  {'City': 'aquidauana',
#   'Lat': -20.47,
#   'Lng': -55.79,
#   'Max Temp': 72.09,
#   'Humidity': 60,
#   'Cloudiness': 7,
#   'Wind Speed': 5.86,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:19'},
#  {'City': 'sept-iles',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 39.2,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:49:12'},
#  {'City': 'nyurba',
#   'Lat': 63.28,
#   'Lng': 118.33,
#   'Max Temp': 5.49,
#   'Humidity': 87,
#   'Cloudiness': 58,
#   'Wind Speed': 10.16,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:19'},
#  {'City': 'ramnagar',
#   'Lat': 29.4,
#   'Lng': 79.12,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 0.74,
#   'Country': 'IN',
#   'Current Description': 'mist',
#   'Date': '2020-11-02 02:52:19'},
#  {'City': 'okhotsk',
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': 23.25,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 19.64,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:19'},
#  {'City': 'hamadan',
#   'Lat': 34.8,
#   'Lng': 48.51,
#   'Max Temp': 39.25,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 0.89,
#   'Country': 'IR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:19'},
#  {'City': 'urumqi',
#   'Lat': 43.8,
#   'Lng': 87.6,
#   'Max Temp': 41,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'CN',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:09'},
#  {'City': 'sovetskiy',
#   'Lat': 61.36,
#   'Lng': 63.58,
#   'Max Temp': 25.63,
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 5.41,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:19'},
#  {'City': 'quilmana',
#   'Lat': -12.95,
#   'Lng': -76.38,
#   'Max Temp': 62.98,
#   'Humidity': 74,
#   'Cloudiness': 58,
#   'Wind Speed': 3.76,
#   'Country': 'PE',
#   'Current Description': 'broken clouds',
#   'Date': '2020-11-02 02:52:19'},
#  {'City': 'cosenza',
#   'Lat': 39.31,
#   'Lng': 16.25,
#   'Max Temp': 54,
#   'Humidity': 86,
#   'Cloudiness': 89,
#   'Wind Speed': 1.01,
#   'Country': 'IT',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:20'},
#  {'City': 'ituango',
#   'Lat': 7.17,
#   'Lng': -75.76,
#   'Max Temp': 62.01,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Country': 'CO',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:20'},
#  {'City': 'dolores',
#   'Lat': -36.31,
#   'Lng': -57.68,
#   'Max Temp': 50.59,
#   'Humidity': 63,
#   'Cloudiness': 14,
#   'Wind Speed': 3.6,
#   'Country': 'AR',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:52:20'},
#  {'City': 'labuhan',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 85.32,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 6.58,
#   'Country': 'ID',
#   'Current Description': 'heavy intensity rain',
#   'Date': '2020-11-02 02:52:20'},
#  {'City': 'svetlogorsk',
#   'Lat': 52.63,
#   'Lng': 29.73,
#   'Max Temp': 43.09,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.47,
#   'Country': 'BY',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:20'},
#  {'City': 'gazli',
#   'Lat': 40.13,
#   'Lng': 63.45,
#   'Max Temp': 51.19,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 8.34,
#   'Country': 'UZ',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:21'},
#  {'City': 'lakes entrance',
#   'Lat': -37.88,
#   'Lng': 147.98,
#   'Max Temp': 71.01,
#   'Humidity': 68,
#   'Cloudiness': 47,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:52:21'},
#  {'City': 'iseyin',
#   'Lat': 7.97,
#   'Lng': 3.6,
#   'Max Temp': 72.23,
#   'Humidity': 98,
#   'Cloudiness': 18,
#   'Wind Speed': 3.22,
#   'Country': 'NG',
#   'Current Description': 'few clouds',
#   'Date': '2020-11-02 02:52:21'},
#  {'City': 'olinda',
#   'Lat': -8.01,
#   'Lng': -34.86,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:51:21'},
#  {'City': 'ust-maya',
#   'Lat': 60.42,
#   'Lng': 134.53,
#   'Max Temp': -2.42,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:21'},
#  {'City': 'guanare',
#   'Lat': 9.04,
#   'Lng': -69.74,
#   'Max Temp': 73.45,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.19,
#   'Country': 'VE',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:21'},
#  {'City': 'insar',
#   'Lat': 53.87,
#   'Lng': 44.37,
#   'Max Temp': 41.88,
#   'Humidity': 91,
#   'Cloudiness': 92,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:22'},
#  {'City': 'tazovskiy',
#   'Lat': 67.47,
#   'Lng': 78.7,
#   'Max Temp': 19.58,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 14.45,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Date': '2020-11-02 02:52:22'},
#  {'City': 'diego de almagro',
#   'Lat': -26.37,
#   'Lng': -70.05,
#   'Max Temp': 54.09,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 0.96,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:22'},
#  {'City': 'bundaberg',
#   'Lat': -24.85,
#   'Lng': 152.35,
#   'Max Temp': 84.2,
#   'Humidity': 51,
#   'Cloudiness': 7,
#   'Wind Speed': 21.92,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:22'},
#  {'City': 'bahia honda',
#   'Lat': 22.9,
#   'Lng': -83.16,
#   'Max Temp': 78.48,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 11.3,
#   'Country': 'CU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:22'},
#  {'City': 'whyalla',
#   'Lat': -33.03,
#   'Lng': 137.58,
#   'Max Temp': 86,
#   'Humidity': 27,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:22'},
#  {'City': 'beruwala',
#   'Lat': 6.48,
#   'Lng': 79.98,
#   'Max Temp': 82.36,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 2.8,
#   'Country': 'LK',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:23'},
#  {'City': 'san rafael',
#   'Lat': -34.62,
#   'Lng': -68.33,
#   'Max Temp': 69.6,
#   'Humidity': 24,
#   'Cloudiness': 50,
#   'Wind Speed': 6.04,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds',
#   'Date': '2020-11-02 02:52:23'},
#  {'City': 'porto velho',
#   'Lat': -8.76,
#   'Lng': -63.9,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Date': '2020-11-02 02:52:13'}]

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  norman wells  65.28 -126.83      3.20        84          75        3.36
# 1   port alfred -33.59   26.89     64.62        82          26       17.25
# 2  puerto ayora  -0.74  -90.35     69.01        91         100        4.00
# 3         bluff -46.60  168.33     55.99        61          48       10.00
# 4      cidreira -30.18  -50.21     61.47        64           2        6.08
# 5        hobart -42.88  147.33     81.00        40           0        9.17
# 6      barcelos  41.54   -8.62     64.40       100          90       10.29
# 7    bredasdorp -34.53   20.04     64.40        82         100       13.87
# 8         sitka  57.05 -135.33     50.00        87          90       25.28
# 9         lamar  33.67  -95.58     50.00        57           1        5.82
#
#   Country   Current Description                 Date
# 0      CA         broken clouds  2020-11-02 02:42:34
# 1      ZA      scattered clouds  2020-11-02 02:42:34
# 2      EC       overcast clouds  2020-11-02 02:42:34
# 3      NZ      scattered clouds  2020-11-02 02:42:34
# 4      BR             clear sky  2020-11-02 02:42:34
# 5      AU             clear sky  2020-11-02 02:42:34
# 6      PT                  mist  2020-11-02 02:42:34
# 7      ZA       overcast clouds  2020-11-02 02:37:58
# 8      US  heavy intensity rain  2020-11-02 02:42:34
# 9      US             clear sky  2020-11-02 02:50:58

# %%
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Date"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    norman wells      CA  65.28 -126.83      3.20        84          75
# 1     port alfred      ZA -33.59   26.89     64.62        82          26
# 2    puerto ayora      EC  -0.74  -90.35     69.01        91         100
# 3           bluff      NZ -46.60  168.33     55.99        61          48
# 4        cidreira      BR -30.18  -50.21     61.47        64           2
# ..            ...     ...    ...     ...       ...       ...         ...
# 689   bahia honda      CU  22.90  -83.16     78.48        86           9
# 690       whyalla      AU -33.03  137.58     86.00        27           1
# 691      beruwala      LK   6.48   79.98     82.36        70           0
# 692    san rafael      AR -34.62  -68.33     69.60        24          50
# 693   porto velho      BR  -8.76  -63.90     77.00        94           0
#
#      Wind Speed Current Description                 Date
# 0          3.36       broken clouds  2020-11-02 02:42:34
# 1         17.25    scattered clouds  2020-11-02 02:42:34
# 2          4.00     overcast clouds  2020-11-02 02:42:34
# 3         10.00    scattered clouds  2020-11-02 02:42:34
# 4          6.08           clear sky  2020-11-02 02:42:34
# ..          ...                 ...                  ...
# 689       11.30           clear sky  2020-11-02 02:52:22
# 690       11.41           clear sky  2020-11-02 02:52:22
# 691        2.80           clear sky  2020-11-02 02:52:23
# 692        6.04    scattered clouds  2020-11-02 02:52:23
# 693        2.24           clear sky  2020-11-02 02:52:13
#
# [694 rows x 10 columns]

# %%
#Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
